# %% [markdown]
# # 📦 CELL 1: SETUP ENVIRONMENT

# %%
# !git clone https://github.com/AS-STUDIO-PRO/AS-STODIO-PRO-V2.git /content/AS-STODIO-PRO-V2
# %cd /content/AS-STODIO-PRO-V2
# !pip install -q gradio librosa

# %% [markdown]
# # 🎬 CELL 2: LAUNCH AS AVATAR STUDIO V2

# %%
# !python /content/AS-STODIO-PRO-V2/demo.py
